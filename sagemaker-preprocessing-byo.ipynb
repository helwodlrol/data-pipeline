# %%
# !cat Dockerfile
# Out:
# FROM python:3.7-slim-buster
#
# LABEL maintainer=cong
#
# RUN apt-get -y update && rm -rf /var/lib/apt/lists/*
#
# RUN pip install pandas && rm -rf /root/.cache
# RUN mkdir /opt/program
#
# ENV PYTHONUNBUFFERED=TRUE
# ENV PYTHONDONTWRITEBYTECODE=TRUE
# ENV PATH="/opt/program:${PATH}"
#
# COPY preprocessing.py /opt/program
# WORKDIR /opt/program

# %%
# %%sh
#
# #!/usr/bin/env bash
#
# # This script shows how to build the Docker image and push it to ECR to be ready for use
# # by SageMaker.
#
# # The argument to this script is the image name. This will be used as the image on the local
# # machine and combined with the account and region to form the repository name for ECR.
# image=sagemaker-preprocessing
#
# if [ "$image" == "" ]
# then
#     echo "Usage: $0 <image-name>"
#     exit 1
# fi
#
# chmod +x preprocessing.py
#
# # Get the account number associated with the current IAM credentials
# account=$(aws sts get-caller-identity --query Account --output text)
#
# if [ $? -ne 0 ]
# then
#     exit 255
# fi
#
#
# # Get the region defined in the current configuration (default to us-west-2 if none defined)
# region=$(aws configure get region)
# region=${region:-us-west-2}
#
#
# fullname="${account}.dkr.ecr.${region}.amazonaws.com/${image}:latest"
#
# # If the repository doesn't exist in ECR, create it.
#
# aws ecr describe-repositories --repository-names "${image}" > /dev/null 2>&1
#
# if [ $? -ne 0 ]
# then
#     aws ecr create-repository --repository-name "${image}" > /dev/null
# fi
#
# # Get the login command from ECR and execute it directly
# $(aws ecr get-login --region ${region} --no-include-email)
#
# # Build the docker image locally with the image name and then push it to ECR
# # with the full name.
#
# docker build  -t ${image} .
# docker tag ${image} ${fullname}
#
# docker push ${fullname}
# Out:
# Login Succeeded
#
# Step 1/10 : FROM python:3.7-slim-buster
#  ---> d7ee20941226
# Step 2/10 : LABEL maintainer=cong
#  ---> Using cache
#  ---> dffc6d3f6427
# Step 3/10 : RUN apt-get -y update && rm -rf /var/lib/apt/lists/*
#  ---> Using cache
#  ---> 3796209ac6de
# Step 4/10 : RUN pip install pandas && rm -rf /root/.cache
#  ---> Using cache
#  ---> fb04ab9aca5a
# Step 5/10 : RUN mkdir /opt/program
#  ---> Using cache
#  ---> a413a5682731
# Step 6/10 : ENV PYTHONUNBUFFERED=TRUE
#  ---> Using cache
#  ---> 163890f6ab60
# Step 7/10 : ENV PYTHONDONTWRITEBYTECODE=TRUE
#  ---> Using cache
#  ---> 9bdfc6711de2
# Step 8/10 : ENV PATH="/opt/program:${PATH}"
#  ---> Using cache
#  ---> b1a501d91e71
# Step 9/10 : COPY preprocessing.py /opt/program
#  ---> 66fd39a749d7
# Step 10/10 : WORKDIR /opt/program
#  ---> Running in cc08a04e551c
# Removing intermediate container cc08a04e551c
#  ---> 93f29c4121cf
# Successfully built 93f29c4121cf
# Successfully tagged sagemaker-preprocessing:latest
# The push refers to repository [169274280855.dkr.ecr.us-east-2.amazonaws.com/sagemaker-preprocessing]
# a47037729c55: Preparing
# 51ed349eb052: Preparing
# 07585042d872: Preparing
# c8fb765467ed: Preparing
# 715414420313: Preparing
# dba4fa00b93a: Preparing
# 9f690547ed37: Preparing
# 6376837eded8: Preparing
# c2adabaecedb: Preparing
# dba4fa00b93a: Waiting
# 9f690547ed37: Waiting
# 6376837eded8: Waiting
# c2adabaecedb: Waiting
# 51ed349eb052: Layer already exists
# 07585042d872: Layer already exists
# 715414420313: Layer already exists
# c8fb765467ed: Layer already exists
# dba4fa00b93a: Layer already exists
# 9f690547ed37: Layer already exists
# 6376837eded8: Layer already exists
# c2adabaecedb: Layer already exists
# a47037729c55: Pushed
# latest: digest: sha256:5a8cd189bd8c94ef18244ead34a2f8990a7482fb0c89605d7700c411fe802298 size: 2204
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store

# %% [markdown]
# ### processing job

# %%
# S3 prefix
prefix = 'DEMO-processing-byo-memory'

# Define IAM role
import boto3

import pandas as pd
from sagemaker import get_execution_role

role = get_execution_role()
role
# Out:
# 'arn:aws:iam::169274280855:role/SageMakerFullAccess'

# %%
import sagemaker as sage

sess = sage.Session()

# %%
WORK_DIRECTORY = 'data'

data_location = sess.upload_data(WORK_DIRECTORY, key_prefix=prefix)
data_location
# Out:
# 's3://sagemaker-us-east-2-169274280855/DEMO-processing-byo-memory'

# %%
account = sess.boto_session.client('sts').get_caller_identity()['Account']
region = sess.boto_session.region_name
image = '{}.dkr.ecr.{}.amazonaws.com/sagemaker-preprocessing:latest'.format(account, region)
image
# Out:
# '169274280855.dkr.ecr.us-east-2.amazonaws.com/sagemaker-preprocessing:latest'

# %%
from sagemaker.processing import ScriptProcessor
from sagemaker.processing import ProcessingInput, ProcessingOutput

script_processor = ScriptProcessor(image_uri=image,
                                    role=role,
                                    instance_count=1,
                                    command=["python3", "-v"],
                                    instance_type='ml.m5.xlarge')

# %%
script_processor.run(code='preprocessing.py',
                    inputs=[ProcessingInput(source='data/memory.dat',destination='/opt/ml/processing/input')],
                    outputs=[ProcessingOutput(source='/opt/ml/processing/output/train')])
# Out:
# Job Name:  sagemaker-preprocessing-2020-05-09-08-15-24-152
# Inputs:  [{'InputName': 'input-1', 'S3Input': {'S3Uri': 's3://sagemaker-us-east-2-169274280855/sagemaker-preprocessing-2020-05-09-08-15-24-152/input/input-1/memory.dat', 'LocalPath': '/opt/ml/processing/input', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3DataDistributionType': 'FullyReplicated', 'S3CompressionType': 'None'}}, {'InputName': 'code', 'S3Input': {'S3Uri': 's3://sagemaker-us-east-2-169274280855/sagemaker-preprocessing-2020-05-09-08-15-24-152/input/code/preprocessing.py', 'LocalPath': '/opt/ml/processing/input/code', 'S3DataType': 'S3Prefix', 'S3InputMode': 'File', 'S3DataDistributionType': 'FullyReplicated', 'S3CompressionType': 'None'}}]
# Outputs:  [{'OutputName': 'output-1', 'S3Output': {'S3Uri': 's3://sagemaker-us-east-2-169274280855/sagemaker-preprocessing-2020-05-09-08-15-24-152/output/output-1', 'LocalPath': '/opt/ml/processing/output/train', 'S3UploadMode': 'EndOfJob'}}]
# ..................
# import _frozen_importlib # frozen
# import _imp # builtin
# import '_thread' # <class '_frozen_importlib.BuiltinImporter'>
# import '_warnings' # <class '_frozen_importlib.BuiltinImporter'>
# import '_weakref' # <class '_frozen_importlib.BuiltinImporter'>
# # installing zipimport hook
# import 'zipimport' # <class '_frozen_importlib.BuiltinImporter'>
# # installed zipimport hook
# import '_frozen_importlib_external' # <class '_frozen_importlib.FrozenImporter'>
# import '_io' # <class '_frozen_importlib.BuiltinImporter'>
# import 'marshal' # <class '_frozen_importlib.BuiltinImporter'>
# import 'posix' # <class '_frozen_importlib.BuiltinImporter'>
# import _thread # previously loaded ('_thread')
# import '_thread' # <class '_frozen_importlib.BuiltinImporter'>
# import _weakref # previously loaded ('_weakref')
# import '_weakref' # <class '_frozen_importlib.BuiltinImporter'>
# # /usr/local/lib/python3.7/encodings/__pycache__/__init__.cpython-37.pyc matches /usr/local/lib/python3.7/encodings/__init__.py
# # code object from '/usr/local/lib/python3.7/encodings/__pycache__/__init__.cpython-37.pyc'
# # /usr/local/lib/python3.7/__pycache__/codecs.cpython-37.pyc matches /usr/local/lib/python3.7/codecs.py
# # code object from '/usr/local/lib/python3.7/__pycache__/codecs.cpython-37.pyc'
# import '_codecs' # <class '_frozen_importlib.BuiltinImporter'>
# import 'codecs' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d9a7350>
# # /usr/local/lib/python3.7/encodings/__pycache__/aliases.cpython-37.pyc matches /usr/local/lib/python3.7/encodings/aliases.py
# # code object from '/usr/local/lib/python3.7/encodings/__pycache__/aliases.cpython-37.pyc'
# import 'encodings.aliases' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d9c55d0>
# import 'encodings' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87da22790>
# # /usr/local/lib/python3.7/encodings/__pycache__/utf_8.cpython-37.pyc matches /usr/local/lib/python3.7/encodings/utf_8.py
# # code object from '/usr/local/lib/python3.7/encodings/__pycache__/utf_8.cpython-37.pyc'
# import 'encodings.utf_8' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d9a7310>
# import '_signal' # <class '_frozen_importlib.BuiltinImporter'>
# # /usr/local/lib/python3.7/encodings/__pycache__/latin_1.cpython-37.pyc matches /usr/local/lib/python3.7/encodings/latin_1.py
# # code object from '/usr/local/lib/python3.7/encodings/__pycache__/latin_1.cpython-37.pyc'
# import 'encodings.latin_1' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d9ccd90>
# # /usr/local/lib/python3.7/__pycache__/io.cpython-37.pyc matches /usr/local/lib/python3.7/io.py
# # code object from '/usr/local/lib/python3.7/__pycache__/io.cpython-37.pyc'
# # /usr/local/lib/python3.7/__pycache__/abc.cpython-37.pyc matches /usr/local/lib/python3.7/abc.py
# # code object from '/usr/local/lib/python3.7/__pycache__/abc.cpython-37.pyc'
# import '_abc' # <class '_frozen_importlib.BuiltinImporter'>
# import 'abc' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d9d17d0>
# import 'io' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d9d1090>
# # /usr/local/lib/python3.7/__pycache__/_bootlocale.cpython-37.pyc matches /usr/local/lib/python3.7/_bootlocale.py
# # code object from '/usr/local/lib/python3.7/__pycache__/_bootlocale.cpython-37.pyc'
# import '_locale' # <class '_frozen_importlib.BuiltinImporter'>
# import '_bootlocale' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d9d4490>
# # /usr/local/lib/python3.7/__pycache__/site.cpython-37.pyc matches /usr/local/lib/python3.7/site.py
# # code object from '/usr/local/lib/python3.7/__pycache__/site.cpython-37.pyc'
# # /usr/local/lib/python3.7/__pycache__/os.cpython-37.pyc matches /usr/local/lib/python3.7/os.py
# # code object from '/usr/local/lib/python3.7/__pycache__/os.cpython-37.pyc'
# # /usr/local/lib/python3.7/__pycache__/stat.cpython-37.pyc matches /usr/local/lib/python3.7/stat.py
# # code object from '/usr/local/lib/python3.7/__pycache__/stat.cpython-37.pyc'
# import '_stat' # <class '_frozen_importlib.BuiltinImporter'>
# import 'stat' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d972a10>
# # /usr/local/lib/python3.7/__pycache__/_collections_abc.cpython-37.pyc matches /usr/local/lib/python3.7/_collections_abc.py
# # code object from '/usr/local/lib/python3.7/__pycache__/_collections_abc.cpython-37.pyc'
# import '_collections_abc' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d976510>
# # /usr/local/lib/python3.7/__pycache__/posixpath.cpython-37.pyc matches /usr/local/lib/python3.7/posixpath.py
# # code object from '/usr/local/lib/python3.7/__pycache__/posixpath.cpython-37.pyc'
# # /usr/local/lib/python3.7/__pycache__/genericpath.cpython-37.pyc matches /usr/local/lib/python3.7/genericpath.py
# # code object from '/usr/local/lib/python3.7/__pycache__/genericpath.cpython-37.pyc'
# import 'genericpath' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d903390>
# import 'posixpath' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d986510>
# import 'os' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d9659d0>
# # /usr/local/lib/python3.7/__pycache__/_sitebuiltins.cpython-37.pyc matches /usr/local/lib/python3.7/_sitebuiltins.py
# # code object from '/usr/local/lib/python3.7/__pycache__/_sitebuiltins.cpython-37.pyc'
# import '_sitebuiltins' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d965f90>
# import 'site' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d9db2d0>
# Python 3.7.7 (default, Apr 23 2020, 14:54:40)
# [GCC 8.3.0] on linux
# Type "help", "copyright", "credits" or "license" for more information.
# # /usr/local/lib/python3.7/json/__pycache__/__init__.cpython-37.pyc matches /usr/local/lib/python3.7/json/__init__.py
# # code object from '/usr/local/lib/python3.7/json/__pycache__/__init__.cpython-37.pyc'
# # /usr/local/lib/python3.7/json/__pycache__/decoder.cpython-37.pyc matches /usr/local/lib/python3.7/json/decoder.py
# # code object from '/usr/local/lib/python3.7/json/__pycache__/decoder.cpython-37.pyc'
# # /usr/local/lib/python3.7/__pycache__/re.cpython-37.pyc matches /usr/local/lib/python3.7/re.py
# # code object from '/usr/local/lib/python3.7/__pycache__/re.cpython-37.pyc'
# # /usr/local/lib/python3.7/__pycache__/enum.cpython-37.pyc matches /usr/local/lib/python3.7/enum.py
# # code object from '/usr/local/lib/python3.7/__pycache__/enum.cpython-37.pyc'
# # /usr/local/lib/python3.7/__pycache__/types.cpython-37.pyc matches /usr/local/lib/python3.7/types.py
# # code object from '/usr/local/lib/python3.7/__pycache__/types.cpython-37.pyc'
# import 'types' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d932710>
# import '_collections' # <class '_frozen_importlib.BuiltinImporter'>
# import 'enum' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d91f790>
# # /usr/local/lib/python3.7/__pycache__/sre_compile.cpython-37.pyc matches /usr/local/lib/python3.7/sre_compile.py
# # code object from '/usr/local/lib/python3.7/__pycache__/sre_compile.cpython-37.pyc'
# import '_sre' # <class '_frozen_importlib.BuiltinImporter'>
# # /usr/local/lib/python3.7/__pycache__/sre_parse.cpython-37.pyc matches /usr/local/lib/python3.7/sre_parse.py
# # code object from '/usr/local/lib/python3.7/__pycache__/sre_parse.cpython-37.pyc'
# # /usr/local/lib/python3.7/__pycache__/sre_constants.cpython-37.pyc matches /usr/local/lib/python3.7/sre_constants.py
# # code object from '/usr/local/lib/python3.7/__pycache__/sre_constants.cpython-37.pyc'
# import 'sre_constants' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d8d8b90>
# import 'sre_parse' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d8cbd10>
# import 'sre_compile' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d92c190>
# # /usr/local/lib/python3.7/__pycache__/functools.cpython-37.pyc matches /usr/local/lib/python3.7/functools.py
# # code object from '/usr/local/lib/python3.7/__pycache__/functools.cpython-37.pyc'
# import '_functools' # <class '_frozen_importlib.BuiltinImporter'>
# # /usr/local/lib/python3.7/collections/__pycache__/__init__.cpython-37.pyc matches /usr/local/lib/python3.7/collections/__init__.py
# # code object from '/usr/local/lib/python3.7/collections/__pycache__/__init__.cpython-37.pyc'
# # /usr/local/lib/python3.7/__pycache__/operator.cpython-37.pyc matches /usr/local/lib/python3.7/operator.py
# # code object from '/usr/local/lib/python3.7/__pycache__/operator.cpython-37.pyc'
# import '_operator' # <class '_frozen_importlib.BuiltinImporter'>
# import 'operator' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d896690>
# # /usr/local/lib/python3.7/__pycache__/keyword.cpython-37.pyc matches /usr/local/lib/python3.7/keyword.py
# # code object from '/usr/local/lib/python3.7/__pycache__/keyword.cpython-37.pyc'
# import 'keyword' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d899350>
# # /usr/local/lib/python3.7/__pycache__/heapq.cpython-37.pyc matches /usr/local/lib/python3.7/heapq.py
# # code object from '/usr/local/lib/python3.7/__pycache__/heapq.cpython-37.pyc'
# # extension module '_heapq' loaded from '/usr/local/lib/python3.7/lib-dynload/_heapq.cpython-37m-x86_64-linux-gnu.so'
# # extension module '_heapq' executed from '/usr/local/lib/python3.7/lib-dynload/_heapq.cpython-37m-x86_64-linux-gnu.so'
# import '_heapq' # <_frozen_importlib_external.ExtensionFileLoader object at 0x7fa87d8a3a50>
# import 'heapq' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d8a2c50>
# import 'itertools' # <class '_frozen_importlib.BuiltinImporter'>
# # /usr/local/lib/python3.7/__pycache__/reprlib.cpython-37.pyc matches /usr/local/lib/python3.7/reprlib.py
# # code object from '/usr/local/lib/python3.7/__pycache__/reprlib.cpython-37.pyc'
# import 'reprlib' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d89d890>
# import 'collections' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d8f56d0>
# import 'functools' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d8d8850>
# # /usr/local/lib/python3.7/__pycache__/copyreg.cpython-37.pyc matches /usr/local/lib/python3.7/copyreg.py
# # code object from '/usr/local/lib/python3.7/__pycache__/copyreg.cpython-37.pyc'
# import 'copyreg' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d8bc290>
# import 're' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d91ab50>
# # /usr/local/lib/python3.7/json/__pycache__/scanner.cpython-37.pyc matches /usr/local/lib/python3.7/json/scanner.py
# # code object from '/usr/local/lib/python3.7/json/__pycache__/scanner.cpython-37.pyc'
# # extension module '_json' loaded from '/usr/local/lib/python3.7/lib-dynload/_json.cpython-37m-x86_64-linux-gnu.so'
# # extension module '_json' executed from '/usr/local/lib/python3.7/lib-dynload/_json.cpython-37m-x86_64-linux-gnu.so'
# import '_json' # <_frozen_importlib_external.ExtensionFileLoader object at 0x7fa87d8bcd50>
# import 'json.scanner' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d8bc810>
# import 'json.decoder' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d918450>
# # /usr/local/lib/python3.7/json/__pycache__/encoder.cpython-37.pyc matches /usr/local/lib/python3.7/json/encoder.py
# # code object from '/usr/local/lib/python3.7/json/__pycache__/encoder.cpython-37.pyc'
# import 'json.encoder' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d91e8d0>
# import 'json' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d938a90>
# # /usr/local/lib/python3.7/__pycache__/argparse.cpython-37.pyc matches /usr/local/lib/python3.7/argparse.py
# # code object from '/usr/local/lib/python3.7/__pycache__/argparse.cpython-37.pyc'
# # /usr/local/lib/python3.7/__pycache__/gettext.cpython-37.pyc matches /usr/local/lib/python3.7/gettext.py
# # code object from '/usr/local/lib/python3.7/__pycache__/gettext.cpython-37.pyc'
# # /usr/local/lib/python3.7/__pycache__/locale.cpython-37.pyc matches /usr/local/lib/python3.7/locale.py
# # code object from '/usr/local/lib/python3.7/__pycache__/locale.cpython-37.pyc'
# import 'locale' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d86ec10>
# import 'gettext' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d863a90>
# import 'argparse' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d845090>
# # /usr/local/lib/python3.7/site-packages/pandas/__pycache__/__init__.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/pandas/__init__.py
# # code object from '/usr/local/lib/python3.7/site-packages/pandas/__pycache__/__init__.cpython-37.pyc'
# # /usr/local/lib/python3.7/site-packages/numpy/__pycache__/__init__.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/__init__.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/__pycache__/__init__.cpython-37.pyc'
# # /usr/local/lib/python3.7/__pycache__/__future__.cpython-37.pyc matches /usr/local/lib/python3.7/__future__.py
# # code object from '/usr/local/lib/python3.7/__pycache__/__future__.cpython-37.pyc'
# import '__future__' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d810650>
# # /usr/local/lib/python3.7/__pycache__/warnings.cpython-37.pyc matches /usr/local/lib/python3.7/warnings.py
# # code object from '/usr/local/lib/python3.7/__pycache__/warnings.cpython-37.pyc'
# import 'warnings' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d810f90>
# # /usr/local/lib/python3.7/site-packages/numpy/__pycache__/_globals.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/_globals.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/__pycache__/_globals.cpython-37.pyc'
# import 'numpy._globals' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d818b10>
# # /usr/local/lib/python3.7/site-packages/numpy/__pycache__/__config__.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/__config__.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/__pycache__/__config__.cpython-37.pyc'
# import 'numpy.__config__' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d81c050>
# # /usr/local/lib/python3.7/site-packages/numpy/__pycache__/version.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/version.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/__pycache__/version.cpython-37.pyc'
# import 'numpy.version' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d81c710>
# # /usr/local/lib/python3.7/site-packages/numpy/__pycache__/_distributor_init.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/_distributor_init.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/__pycache__/_distributor_init.cpython-37.pyc'
# import 'numpy._distributor_init' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d81c890>
# # /usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/__init__.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/core/__init__.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/__init__.cpython-37.pyc'
# # /usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/multiarray.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/core/multiarray.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/multiarray.cpython-37.pyc'
# # /usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/overrides.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/core/overrides.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/overrides.cpython-37.pyc'
# # /usr/local/lib/python3.7/__pycache__/textwrap.cpython-37.pyc matches /usr/local/lib/python3.7/textwrap.py
# # code object from '/usr/local/lib/python3.7/__pycache__/textwrap.cpython-37.pyc'
# import 'textwrap' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d7abfd0>
# # /usr/local/lib/python3.7/__pycache__/datetime.cpython-37.pyc matches /usr/local/lib/python3.7/datetime.py
# # code object from '/usr/local/lib/python3.7/__pycache__/datetime.cpython-37.pyc'
# import 'time' # <class '_frozen_importlib.BuiltinImporter'>
# # extension module 'math' loaded from '/usr/local/lib/python3.7/lib-dynload/math.cpython-37m-x86_64-linux-gnu.so'
# # extension module 'math' executed from '/usr/local/lib/python3.7/lib-dynload/math.cpython-37m-x86_64-linux-gnu.so'
# import 'math' # <_frozen_importlib_external.ExtensionFileLoader object at 0x7fa87d7dff10>
# # extension module '_datetime' loaded from '/usr/local/lib/python3.7/lib-dynload/_datetime.cpython-37m-x86_64-linux-gnu.so'
# # extension module '_datetime' executed from '/usr/local/lib/python3.7/lib-dynload/_datetime.cpython-37m-x86_64-linux-gnu.so'
# import '_datetime' # <_frozen_importlib_external.ExtensionFileLoader object at 0x7fa8738ac350>
# import 'datetime' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d7aefd0>
# # extension module 'numpy.core._multiarray_umath' loaded from '/usr/local/lib/python3.7/site-packages/numpy/core/_multiarray_umath.cpython-37m-x86_64-linux-gnu.so'
# # extension module 'numpy.core._multiarray_umath' executed from '/usr/local/lib/python3.7/site-packages/numpy/core/_multiarray_umath.cpython-37m-x86_64-linux-gnu.so'
# import 'numpy.core._multiarray_umath' # <_frozen_importlib_external.ExtensionFileLoader object at 0x7fa87d7aea10>
# # /usr/local/lib/python3.7/site-packages/numpy/compat/__pycache__/__init__.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/compat/__init__.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/compat/__pycache__/__init__.cpython-37.pyc'
# # /usr/local/lib/python3.7/site-packages/numpy/compat/__pycache__/_inspect.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/compat/_inspect.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/compat/__pycache__/_inspect.cpython-37.pyc'
# import 'numpy.compat._inspect' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d7cf490>
# # /usr/local/lib/python3.7/site-packages/numpy/compat/__pycache__/py3k.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/compat/py3k.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/compat/__pycache__/py3k.cpython-37.pyc'
# # /usr/local/lib/python3.7/__pycache__/pathlib.cpython-37.pyc matches /usr/local/lib/python3.7/pathlib.py
# # code object from '/usr/local/lib/python3.7/__pycache__/pathlib.cpython-37.pyc'
# # /usr/local/lib/python3.7/__pycache__/fnmatch.cpython-37.pyc matches /usr/local/lib/python3.7/fnmatch.py
# # code object from '/usr/local/lib/python3.7/__pycache__/fnmatch.cpython-37.pyc'
# import 'fnmatch' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa8738de750>
# # /usr/local/lib/python3.7/__pycache__/ntpath.cpython-37.pyc matches /usr/local/lib/python3.7/ntpath.py
# # code object from '/usr/local/lib/python3.7/__pycache__/ntpath.cpython-37.pyc'
# import 'ntpath' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa8738ded50>
# import 'errno' # <class '_frozen_importlib.BuiltinImporter'>
# # /usr/local/lib/python3.7/urllib/__pycache__/__init__.cpython-37.pyc matches /usr/local/lib/python3.7/urllib/__init__.py
# # code object from '/usr/local/lib/python3.7/urllib/__pycache__/__init__.cpython-37.pyc'
# import 'urllib' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa873855450>
# # /usr/local/lib/python3.7/urllib/__pycache__/parse.cpython-37.pyc matches /usr/local/lib/python3.7/urllib/parse.py
# # code object from '/usr/local/lib/python3.7/urllib/__pycache__/parse.cpython-37.pyc'
# import 'urllib.parse' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa873855490>
# import 'pathlib' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d7c4f90>
# # /usr/local/lib/python3.7/__pycache__/pickle.cpython-37.pyc matches /usr/local/lib/python3.7/pickle.py
# # code object from '/usr/local/lib/python3.7/__pycache__/pickle.cpython-37.pyc'
# # /usr/local/lib/python3.7/__pycache__/struct.cpython-37.pyc matches /usr/local/lib/python3.7/struct.py
# # code object from '/usr/local/lib/python3.7/__pycache__/struct.cpython-37.pyc'
# # extension module '_struct' loaded from '/usr/local/lib/python3.7/lib-dynload/_struct.cpython-37m-x86_64-linux-gnu.so'
# # extension module '_struct' executed from '/usr/local/lib/python3.7/lib-dynload/_struct.cpython-37m-x86_64-linux-gnu.so'
# import '_struct' # <_frozen_importlib_external.ExtensionFileLoader object at 0x7fa873811650>
# import 'struct' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa873811210>
# # /usr/local/lib/python3.7/__pycache__/_compat_pickle.cpython-37.pyc matches /usr/local/lib/python3.7/_compat_pickle.py
# # code object from '/usr/local/lib/python3.7/__pycache__/_compat_pickle.cpython-37.pyc'
# import '_compat_pickle' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa8738117d0>
# # extension module '_pickle' loaded from '/usr/local/lib/python3.7/lib-dynload/_pickle.cpython-37m-x86_64-linux-gnu.so'
# # extension module '_pickle' executed from '/usr/local/lib/python3.7/lib-dynload/_pickle.cpython-37m-x86_64-linux-gnu.so'
# import '_pickle' # <_frozen_importlib_external.ExtensionFileLoader object at 0x7fa873814e50>
# import 'pickle' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa8738ac890>
# import 'numpy.compat.py3k' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d7c7390>
# import 'numpy.compat' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d7cf410>
# import 'numpy.core.overrides' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d7ab710>
# import 'numpy.core.multiarray' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d8243d0>
# # /usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/umath.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/core/umath.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/umath.cpython-37.pyc'
# import 'numpy.core.umath' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d821bd0>
# # /usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/numerictypes.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/core/numerictypes.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/numerictypes.cpython-37.pyc'
# # /usr/local/lib/python3.7/__pycache__/numbers.cpython-37.pyc matches /usr/local/lib/python3.7/numbers.py
# # code object from '/usr/local/lib/python3.7/__pycache__/numbers.cpython-37.pyc'
# import 'numbers' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa873846410>
# # /usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/_string_helpers.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/core/_string_helpers.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/_string_helpers.cpython-37.pyc'
# import 'numpy.core._string_helpers' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa8737ae990>
# # /usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/_type_aliases.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/core/_type_aliases.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/_type_aliases.cpython-37.pyc'
# # /usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/_dtype.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/core/_dtype.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/_dtype.cpython-37.pyc'
# import 'numpy.core._dtype' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa8737bc610>
# import 'numpy.core._type_aliases' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa8737aecd0>
# import 'numpy.core.numerictypes' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d7ab4d0>
# # /usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/numeric.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/core/numeric.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/numeric.cpython-37.pyc'
# # /usr/local/lib/python3.7/__pycache__/contextlib.cpython-37.pyc matches /usr/local/lib/python3.7/contextlib.py
# # code object from '/usr/local/lib/python3.7/__pycache__/contextlib.cpython-37.pyc'
# import 'contextlib' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa8737d2050>
# # /usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/shape_base.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/core/shape_base.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/shape_base.cpython-37.pyc'
# # /usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/_asarray.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/core/_asarray.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/_asarray.cpython-37.pyc'
# import 'numpy.core._asarray' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87376b9d0>
# # /usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/fromnumeric.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/core/fromnumeric.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/fromnumeric.cpython-37.pyc'
# # /usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/_methods.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/core/_methods.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/_methods.cpython-37.pyc'
# # /usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/_exceptions.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/core/_exceptions.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/_exceptions.cpython-37.pyc'
# import 'numpy.core._exceptions' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa873782510>
# import 'numpy.core._methods' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87377e290>
# import 'numpy.core.fromnumeric' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa873770150>
# import 'numpy.core.shape_base' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa8737dda50>
# # /usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/_ufunc_config.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/core/_ufunc_config.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/_ufunc_config.cpython-37.pyc'
# # /usr/local/lib/python3.7/collections/__pycache__/abc.cpython-37.pyc matches /usr/local/lib/python3.7/collections/abc.py
# # code object from '/usr/local/lib/python3.7/collections/__pycache__/abc.cpython-37.pyc'
# import 'collections.abc' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa8737aa550>
# import 'numpy.core._ufunc_config' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87376bf50>
# # /usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/arrayprint.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/core/arrayprint.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/arrayprint.cpython-37.pyc'
# import 'numpy.core.arrayprint' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa8737aae10>
# import 'numpy.core.numeric' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa873846150>
# # /usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/defchararray.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/core/defchararray.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/defchararray.cpython-37.pyc'
# import 'numpy.core.defchararray' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa8737d0ed0>
# # /usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/records.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/core/records.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/records.cpython-37.pyc'
# import 'numpy.core.records' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa873764b50>
# # /usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/memmap.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/core/memmap.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/memmap.cpython-37.pyc'
# import 'numpy.core.memmap' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa873708590>
# # /usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/function_base.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/core/function_base.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/function_base.cpython-37.pyc'
# import 'numpy.core.function_base' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa873708e90>
# # /usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/machar.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/core/machar.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/machar.cpython-37.pyc'
# import 'numpy.core.machar' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87370d850>
# # /usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/getlimits.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/core/getlimits.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/getlimits.cpython-37.pyc'
# import 'numpy.core.getlimits' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa8737125d0>
# # /usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/einsumfunc.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/core/einsumfunc.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/einsumfunc.cpython-37.pyc'
# import 'numpy.core.einsumfunc' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa8737180d0>
# # /usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/_add_newdocs.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/core/_add_newdocs.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/_add_newdocs.cpython-37.pyc'
# # extension module 'numpy.core._multiarray_tests' loaded from '/usr/local/lib/python3.7/site-packages/numpy/core/_multiarray_tests.cpython-37m-x86_64-linux-gnu.so'
# # extension module 'numpy.core._multiarray_tests' executed from '/usr/local/lib/python3.7/site-packages/numpy/core/_multiarray_tests.cpython-37m-x86_64-linux-gnu.so'
# import 'numpy.core._multiarray_tests' # <_frozen_importlib_external.ExtensionFileLoader object at 0x7fa8737279d0>
# import 'numpy.core._add_newdocs' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa873721f90>
# # /usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/_dtype_ctypes.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/core/_dtype_ctypes.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/_dtype_ctypes.cpython-37.pyc'
# # extension module '_ctypes' loaded from '/usr/local/lib/python3.7/lib-dynload/_ctypes.cpython-37m-x86_64-linux-gnu.so'
# # extension module '_ctypes' executed from '/usr/local/lib/python3.7/lib-dynload/_ctypes.cpython-37m-x86_64-linux-gnu.so'
# import '_ctypes' # <_frozen_importlib_external.ExtensionFileLoader object at 0x7fa8736918d0>
# # /usr/local/lib/python3.7/ctypes/__pycache__/__init__.cpython-37.pyc matches /usr/local/lib/python3.7/ctypes/__init__.py
# # code object from '/usr/local/lib/python3.7/ctypes/__pycache__/__init__.cpython-37.pyc'
# # /usr/local/lib/python3.7/ctypes/__pycache__/_endian.cpython-37.pyc matches /usr/local/lib/python3.7/ctypes/_endian.py
# # code object from '/usr/local/lib/python3.7/ctypes/__pycache__/_endian.cpython-37.pyc'
# import 'ctypes._endian' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa8736aec90>
# import 'ctypes' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa873683850>
# import 'numpy.core._dtype_ctypes' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa873727690>
# # /usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/_internal.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/core/_internal.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/core/__pycache__/_internal.cpython-37.pyc'
# # /usr/local/lib/python3.7/__pycache__/platform.cpython-37.pyc matches /usr/local/lib/python3.7/platform.py
# # code object from '/usr/local/lib/python3.7/__pycache__/platform.cpython-37.pyc'
# # /usr/local/lib/python3.7/__pycache__/subprocess.cpython-37.pyc matches /usr/local/lib/python3.7/subprocess.py
# # code object from '/usr/local/lib/python3.7/__pycache__/subprocess.cpython-37.pyc'
# # /usr/local/lib/python3.7/__pycache__/signal.cpython-37.pyc matches /usr/local/lib/python3.7/signal.py
# # code object from '/usr/local/lib/python3.7/__pycache__/signal.cpython-37.pyc'
# import 'signal' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87343e090>
# # extension module '_posixsubprocess' loaded from '/usr/local/lib/python3.7/lib-dynload/_posixsubprocess.cpython-37m-x86_64-linux-gnu.so'
# # extension module '_posixsubprocess' executed from '/usr/local/lib/python3.7/lib-dynload/_posixsubprocess.cpython-37m-x86_64-linux-gnu.so'
# import '_posixsubprocess' # <_frozen_importlib_external.ExtensionFileLoader object at 0x7fa87343e190>
# # extension module 'select' loaded from '/usr/local/lib/python3.7/lib-dynload/select.cpython-37m-x86_64-linux-gnu.so'
# # extension module 'select' executed from '/usr/local/lib/python3.7/lib-dynload/select.cpython-37m-x86_64-linux-gnu.so'
# import 'select' # <_frozen_importlib_external.ExtensionFileLoader object at 0x7fa87343ee90>
# # /usr/local/lib/python3.7/__pycache__/selectors.cpython-37.pyc matches /usr/local/lib/python3.7/selectors.py
# # code object from '/usr/local/lib/python3.7/__pycache__/selectors.cpython-37.pyc'
# import 'selectors' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa8734476d0>
# # /usr/local/lib/python3.7/__pycache__/threading.cpython-37.pyc matches /usr/local/lib/python3.7/threading.py
# # code object from '/usr/local/lib/python3.7/__pycache__/threading.cpython-37.pyc'
# # /usr/local/lib/python3.7/__pycache__/traceback.cpython-37.pyc matches /usr/local/lib/python3.7/traceback.py
# # code object from '/usr/local/lib/python3.7/__pycache__/traceback.cpython-37.pyc'
# # /usr/local/lib/python3.7/__pycache__/linecache.cpython-37.pyc matches /usr/local/lib/python3.7/linecache.py
# # code object from '/usr/local/lib/python3.7/__pycache__/linecache.cpython-37.pyc'
# # /usr/local/lib/python3.7/__pycache__/tokenize.cpython-37.pyc matches /usr/local/lib/python3.7/tokenize.py
# # code object from '/usr/local/lib/python3.7/__pycache__/tokenize.cpython-37.pyc'
# # /usr/local/lib/python3.7/__pycache__/token.cpython-37.pyc matches /usr/local/lib/python3.7/token.py
# # code object from '/usr/local/lib/python3.7/__pycache__/token.cpython-37.pyc'
# import 'token' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa8733ee690>
# import 'tokenize' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa8733e4390>
# import 'linecache' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa8733dde10>
# import 'traceback' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa8733d2fd0>
# # /usr/local/lib/python3.7/__pycache__/_weakrefset.cpython-37.pyc matches /usr/local/lib/python3.7/_weakrefset.py
# # code object from '/usr/local/lib/python3.7/__pycache__/_weakrefset.cpython-37.pyc'
# import '_weakrefset' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa8733e4210>
# import 'threading' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87344e6d0>
# import 'subprocess' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa8734297d0>
# import 'platform' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87341f790>
# import 'numpy.core._internal' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa873683950>
# # /usr/local/lib/python3.7/site-packages/numpy/__pycache__/_pytesttester.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/_pytesttester.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/__pycache__/_pytesttester.cpython-37.pyc'
# import 'numpy._pytesttester' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa873430450>
# import 'numpy.core' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87d81ca10>
# # /usr/local/lib/python3.7/site-packages/numpy/lib/__pycache__/__init__.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/lib/__init__.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/lib/__pycache__/__init__.cpython-37.pyc'
# # /usr/local/lib/python3.7/site-packages/numpy/lib/__pycache__/mixins.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/lib/mixins.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/lib/__pycache__/mixins.cpython-37.pyc'
# import 'numpy.lib.mixins' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa8733fda10>
# # /usr/local/lib/python3.7/site-packages/numpy/lib/__pycache__/scimath.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/lib/scimath.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/lib/__pycache__/scimath.cpython-37.pyc'
# # /usr/local/lib/python3.7/site-packages/numpy/lib/__pycache__/type_check.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/lib/type_check.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/lib/__pycache__/type_check.cpython-37.pyc'
# # /usr/local/lib/python3.7/site-packages/numpy/lib/__pycache__/ufunclike.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/lib/ufunclike.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/lib/__pycache__/ufunclike.cpython-37.pyc'
# import 'numpy.lib.ufunclike' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa873398810>
# import 'numpy.lib.type_check' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa873396110>
# import 'numpy.lib.scimath' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa8733fddd0>
# # /usr/local/lib/python3.7/site-packages/numpy/lib/__pycache__/index_tricks.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/lib/index_tricks.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/lib/__pycache__/index_tricks.cpython-37.pyc'
# # /usr/local/lib/python3.7/site-packages/numpy/matrixlib/__pycache__/__init__.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/matrixlib/__init__.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/matrixlib/__pycache__/__init__.cpython-37.pyc'
# # /usr/local/lib/python3.7/site-packages/numpy/matrixlib/__pycache__/defmatrix.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/matrixlib/defmatrix.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/matrixlib/__pycache__/defmatrix.cpython-37.pyc'
# # code object from /usr/local/lib/python3.7/ast.py
# import '_ast' # <class '_frozen_importlib.BuiltinImporter'>
# import 'ast' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa8733b4dd0>
# # /usr/local/lib/python3.7/site-packages/numpy/linalg/__pycache__/__init__.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/linalg/__init__.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/linalg/__pycache__/__init__.cpython-37.pyc'
# # /usr/local/lib/python3.7/site-packages/numpy/linalg/__pycache__/linalg.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/linalg/linalg.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/linalg/__pycache__/linalg.cpython-37.pyc'
# # /usr/local/lib/python3.7/site-packages/numpy/lib/__pycache__/twodim_base.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/lib/twodim_base.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/lib/__pycache__/twodim_base.cpython-37.pyc'
# import 'numpy.lib.twodim_base' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa873310c50>
# # extension module 'numpy.linalg.lapack_lite' loaded from '/usr/local/lib/python3.7/site-packages/numpy/linalg/lapack_lite.cpython-37m-x86_64-linux-gnu.so'
# # extension module 'numpy.linalg.lapack_lite' executed from '/usr/local/lib/python3.7/site-packages/numpy/linalg/lapack_lite.cpython-37m-x86_64-linux-gnu.so'
# import 'numpy.linalg.lapack_lite' # <_frozen_importlib_external.ExtensionFileLoader object at 0x7fa87331a290>
# # extension module 'numpy.linalg._umath_linalg' loaded from '/usr/local/lib/python3.7/site-packages/numpy/linalg/_umath_linalg.cpython-37m-x86_64-linux-gnu.so'
# # extension module 'numpy.linalg._umath_linalg' executed from '/usr/local/lib/python3.7/site-packages/numpy/linalg/_umath_linalg.cpython-37m-x86_64-linux-gnu.so'
# import 'numpy.linalg._umath_linalg' # <_frozen_importlib_external.ExtensionFileLoader object at 0x7fa87331a510>
# import 'numpy.linalg.linalg' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa8733c2c10>
# import 'numpy.linalg' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa8733c2790>
# import 'numpy.matrixlib.defmatrix' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa8733acc50>
# import 'numpy.matrixlib' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa8733ac790>
# # /usr/local/lib/python3.7/site-packages/numpy/lib/__pycache__/function_base.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/lib/function_base.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/lib/__pycache__/function_base.cpython-37.pyc'
# # /usr/local/lib/python3.7/site-packages/numpy/lib/__pycache__/histograms.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/lib/histograms.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/lib/__pycache__/histograms.cpython-37.pyc'
# import 'numpy.lib.histograms' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87333ff90>
# import 'numpy.lib.function_base' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa8733b4c50>
# # /usr/local/lib/python3.7/site-packages/numpy/lib/__pycache__/stride_tricks.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/lib/stride_tricks.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/lib/__pycache__/stride_tricks.cpython-37.pyc'
# import 'numpy.lib.stride_tricks' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87333fc90>
# import 'numpy.lib.index_tricks' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa873398610>
# # /usr/local/lib/python3.7/site-packages/numpy/lib/__pycache__/nanfunctions.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/lib/nanfunctions.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/lib/__pycache__/nanfunctions.cpython-37.pyc'
# import 'numpy.lib.nanfunctions' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87335ce10>
# # /usr/local/lib/python3.7/site-packages/numpy/lib/__pycache__/shape_base.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/lib/shape_base.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/lib/__pycache__/shape_base.cpython-37.pyc'
# import 'numpy.lib.shape_base' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87336e310>
# # /usr/local/lib/python3.7/site-packages/numpy/lib/__pycache__/polynomial.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/lib/polynomial.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/lib/__pycache__/polynomial.cpython-37.pyc'
# import 'numpy.lib.polynomial' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa87337f890>
# # /usr/local/lib/python3.7/site-packages/numpy/lib/__pycache__/utils.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/lib/utils.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/lib/__pycache__/utils.cpython-37.pyc'
# import 'numpy.lib.utils' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa872e99550>
# # /usr/local/lib/python3.7/site-packages/numpy/lib/__pycache__/arraysetops.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/lib/arraysetops.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/lib/__pycache__/arraysetops.cpython-37.pyc'
# import 'numpy.lib.arraysetops' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa872ea8150>
# # /usr/local/lib/python3.7/site-packages/numpy/lib/__pycache__/npyio.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/lib/npyio.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/lib/__pycache__/npyio.cpython-37.pyc'
# # /usr/local/lib/python3.7/__pycache__/weakref.cpython-37.pyc matches /usr/local/lib/python3.7/weakref.py
# # code object from '/usr/local/lib/python3.7/__pycache__/weakref.cpython-37.pyc'
# import 'weakref' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa872ec38d0>
# # /usr/local/lib/python3.7/site-packages/numpy/lib/__pycache__/format.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/lib/format.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/lib/__pycache__/format.cpython-37.pyc'
# import 'numpy.lib.format' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa872ecfe10>
# # /usr/local/lib/python3.7/site-packages/numpy/lib/__pycache__/_datasource.cpython-37.pyc matches /usr/local/lib/python3.7/site-packages/numpy/lib/_datasource.py
# # code object from '/usr/local/lib/python3.7/site-packages/numpy/lib/__pycache__/_datasource.cpython-37.pyc'
# # /usr/local/lib/python3.7/__pycache__/shutil.cpython-37.pyc matches /usr/local/lib/python3.7/shutil.py
# # code object from '/usr/local/lib/python3.7/__pycache__/shutil.cpython-37.pyc'
# # extension module 'zlib' loaded from '/usr/local/lib/python3.7/lib-dynload/zlib.cpython-37m-x86_64-linux-gnu.so'
# # extension module 'zlib' executed from '/usr/local/lib/python3.7/lib-dynload/zlib.cpython-37m-x86_64-linux-gnu.so'
# import 'zlib' # <_frozen_importlib_external.ExtensionFileLoader object at 0x7fa872e71c10>
# # /usr/local/lib/python3.7/__pycache__/bz2.cpython-37.pyc matches /usr/local/lib/python3.7/bz2.py
# # code object from '/usr/local/lib/python3.7/__pycache__/bz2.cpython-37.pyc'
# # /usr/local/lib/python3.7/__pycache__/_compression.cpython-37.pyc matches /usr/local/lib/python3.7/_compression.py
# # code object from '/usr/local/lib/python3.7/__pycache__/_compression.cpython-37.pyc'
# import '_compression' # <_frozen_importlib_external.SourceFileLoader object at 0x7fa872e7d610>
# # extension module '_bz2' loaded from '/usr/local/lib/python3.7/lib-dynload/_bz2.cpython-37m-x86_64-linux-gnu.so'
# # extension module '_bz2' executed from '/usr/local/lib/python3.7/lib-dynload/_bz2.cpython-37m-x86_64-linux-gnu.so'
# import '_bz2' # <_frozen_importlib_external.ExtensionFileLoader object at 0x7fa872e82050>
# ...
# # destroy pandas.core.indexes.extension
# # destroy pandas.core.indexes.category
# # destroy pandas.core.indexes.numeric
# # destroy pandas.core.indexes.datetimelike
# # destroy pandas.core.indexes.datetimes
# # destroy pandas.core.indexes.multi
# # destroy pandas.core.indexes.timedeltas
# # destroy pandas.core.indexes.interval
# # destroy pandas.core.indexes.period
# # destroy pandas.core.indexes.range
# # destroy pandas.core.indexes.api
# # destroy pandas.core.indexes.accessors
# # destroy pandas.core.strings
# # destroy pandas.core.arrays
# # destroy pandas.core.arrays.base
# # destroy pandas.core.arrays.masked
# # destroy pandas.core.arrays.boolean
# # destroy pandas.core.arrays.categorical
# # destroy pandas.core.arrays._ranges
# # destroy pandas.core.arrays.datetimes
# # destroy pandas.core.arrays.integer
# # destroy pandas.core.arrays.interval
# # destroy pandas.core.arrays.numpy_
# # destroy pandas.core.arrays.period
# # destroy pandas.core.arrays.sparse
# # destroy pandas.core.arrays.sparse.dtype
# # destroy pandas.core.arrays.sparse.array
# # destroy pandas.core.arrays.sparse.accessor
# # destroy pandas.core.arrays.string_
# # destroy pandas.core.arrays.timedeltas
# # destroy pandas.core.internals
# # destroy pandas.core.internals.blocks
# # destroy pandas.core.internals.concat
# # destroy pandas.core.internals.managers
# # destroy pandas.core.internals.construction
# # destroy pandas.core.window
# # destroy pandas.core.window.common
# # destroy pandas.core.window.indexers
# # destroy pandas.core.window.numba_
# # destroy pandas.core.window.rolling
# # destroy pandas.core.window.ewm
# # destroy pandas.core.window.expanding
# # destroy pandas.core.series
# # destroy pandas.core.frame
# # destroy pandas.core.api
# # destroy pandas.core.computation
# # destroy pandas.core.computation.common
# # destroy pandas.core.computation.align
# # destroy pandas.core.computation.engines
# # destroy pandas.core.computation.parsing
# # destroy pandas.core.computation.eval
# # destroy pandas.core.computation.api
# # destroy pandas.core.computation.pytables
# # destroy pandas.core.reshape
# # destroy pandas.core.reshape.concat
# # destroy pandas.core.reshape.melt
# # destroy pandas.core.reshape.merge
# # destroy pandas.core.reshape.util
# # destroy pandas.core.reshape.pivot
# # destroy pandas.core.reshape.reshape
# # destroy pandas.core.reshape.tile
# # destroy pandas.core.reshape.api
# # destroy pandas.core.apply
# # destroy pandas.errors
# # destroy pandas.util
# # destroy pandas.io
# # destroy pandas.io.formats
# # destroy pandas.io.formats.csvs
# # destroy pandas.io.clipboards
# # destroy pandas.io.date_converters
# # destroy pandas.io.parsers
# # destroy pandas.io.excel
# # destroy pandas.io.excel._util
# # destroy pandas.io.excel._odfreader
# # destroy pandas.io.excel._openpyxl
# # destroy pandas.io.excel._xlrd
# # destroy pandas.io.excel._pyxlsb
# # destroy pandas.io.excel._base
# # destroy pandas.io.excel._xlsxwriter
# # destroy pandas.io.excel._xlwt
# # destroy pandas.io.feather_format
# # destroy pandas.io.gbq
# # destroy pandas.io.html
# # destroy pandas.io.json
# # destroy pandas.io.json._normalize
# # destroy pandas.io.json._table_schema
# # destroy pandas.io.json._json
# # destroy pandas.io.orc
# # destroy pandas.io.parquet
# # destroy pandas.io.pickle
# # destroy pandas.io.pytables
# # destroy pandas.io.sas
# # destroy pandas.io.sas.sasreader
# # destroy pandas.io.spss
# # destroy pandas.io.sql
# # destroy pandas.io.stata
# # destroy pandas.io.api
# # destroy pandas.tseries
# # destroy pandas.tseries.api
# # destroy pandas.arrays
# # destroy pandas.plotting
# # destroy pandas.plotting._core
# # destroy pandas.plotting._misc
# # destroy pandas.tseries.offsets
# # destroy pandas.api
# # destroy pandas.api.extensions
# # destroy pandas.api.indexers
# # destroy pandas.api.types
# # destroy pandas.testing
# # cleanup[3] wiping numpy
# # destroy numpy._globals
# # destroy numpy._distributor_init
# # destroy numpy._pytesttester
# # destroy numpy.__config__
# # destroy numpy.version
# # destroy numpy.compat
# # destroy numpy.compat._inspect
# # destroy numpy.compat.py3k
# # destroy numpy.core
# # destroy numpy.lib
# # destroy numpy.lib.mixins
# # destroy numpy.lib.ufunclike
# # destroy numpy.lib.type_check
# # destroy numpy.lib.twodim_base
# # destroy numpy.lib.histograms
# # destroy numpy.lib.stride_tricks
# # destroy numpy.lib.index_tricks
# # destroy numpy.lib.nanfunctions
# # destroy numpy.lib.shape_base
# # destroy numpy.lib.polynomial
# # destroy numpy.lib.utils
# # destroy numpy.lib.arraysetops
# # destroy numpy.lib._datasource
# # destroy numpy.lib._iotools
# # destroy numpy.lib.npyio
# # destroy numpy.lib.financial
# # destroy numpy.lib.arrayterator
# # destroy numpy.lib.arraypad
# # destroy numpy.lib._version
# # destroy numpy.lib.scimath
# # destroy numpy.fft
# # destroy numpy.fft._pocketfft
# # destroy numpy.fft.helper
# # destroy numpy.polynomial
# # destroy numpy.polynomial._polybase
# # destroy numpy.polynomial.polynomial
# # destroy numpy.polynomial.chebyshev
# # destroy numpy.polynomial.legendre
# # destroy numpy.polynomial.hermite
# # destroy numpy.polynomial.hermite_e
# # destroy numpy.polynomial.laguerre
# # destroy numpy.random
# # destroy numpy.ctypeslib
# # cleanup[3] wiping warnings
# # cleanup[3] wiping numpy.core.multiarray
# # cleanup[3] wiping numpy.core.overrides
# # cleanup[3] wiping textwrap
# # cleanup[3] wiping datetime
# # cleanup[3] wiping time
# # cleanup[3] wiping math
# # cleanup[3] wiping numpy.core._multiarray_umath
# # cleanup[3] wiping pathlib
# # destroy _stat
# # cleanup[3] wiping fnmatch
# # cleanup[3] wiping ntpath
# # destroy genericpath
# # cleanup[3] wiping errno
# # cleanup[3] wiping pickle
# # destroy _compat_pickle
# # cleanup[3] wiping struct
# # cleanup[3] wiping _struct
# # cleanup[3] wiping _pickle
# # destroy _pickle
# # cleanup[3] wiping numpy.core.umath
# # cleanup[3] wiping numpy.core.numerictypes
# # cleanup[3] wiping numbers
# # cleanup[3] wiping numpy.core._string_helpers
# # cleanup[3] wiping numpy.core._type_aliases
# # cleanup[3] wiping numpy.core._dtype
# # cleanup[3] wiping numpy.core.numeric
# # cleanup[3] wiping contextlib
# # cleanup[3] wiping numpy.core.shape_base
# # cleanup[3] wiping numpy.core._asarray
# # cleanup[3] wiping numpy.core.fromnumeric
# # cleanup[3] wiping numpy.core._methods
# # cleanup[3] wiping numpy.core._exceptions
# # cleanup[3] wiping numpy.core._ufunc_config
# # cleanup[3] wiping collections.abc
# # cleanup[3] wiping numpy.core.arrayprint
# # cleanup[3] wiping numpy.core.defchararray
# # cleanup[3] wiping numpy.core.records
# # cleanup[3] wiping numpy.core.function_base
# # cleanup[3] wiping numpy.core.machar
# # cleanup[3] wiping numpy.core.getlimits
# # cleanup[3] wiping numpy.core.einsumfunc
# # cleanup[3] wiping numpy.core._add_newdocs
# # cleanup[3] wiping numpy.core._multiarray_tests
# # cleanup[3] wiping numpy.core._dtype_ctypes
# # cleanup[3] wiping _ctypes
# # cleanup[3] wiping ctypes
# # destroy ctypes._endian
# # cleanup[3] wiping numpy.core._internal
# # cleanup[3] wiping platform
# # cleanup[3] wiping subprocess
# # destroy signal
# # destroy selectors
# # cleanup[3] wiping _posixsubprocess
# # destroy _posixsubprocess
# # cleanup[3] wiping select
# # cleanup[3] wiping threading
# # cleanup[3] wiping linecache
# # cleanup[3] wiping tokenize
# # cleanup[3] wiping token
# # cleanup[3] wiping numpy.matrixlib
# # destroy numpy.matrixlib.defmatrix
# # cleanup[3] wiping ast
# # cleanup[3] wiping numpy.linalg
# # destroy numpy.linalg.linalg
# # cleanup[3] wiping numpy.linalg.lapack_lite
# # cleanup[3] wiping numpy.linalg._umath_linalg
# # cleanup[3] wiping numpy.lib.function_base
# # cleanup[3] wiping weakref
# # destroy _collections_abc
# # cleanup[3] wiping numpy.lib.format
# # cleanup[3] wiping shutil
# # destroy fnmatch
# # cleanup[3] wiping zlib
# # cleanup[3] wiping bz2
# # cleanup[3] wiping _compression
# # cleanup[3] wiping lzma
# # cleanup[3] wiping _lzma
# # destroy _lzma
# # cleanup[3] wiping pwd
# # destroy pwd
# # cleanup[3] wiping grp
# # destroy grp
# # cleanup[3] wiping decimal
# # cleanup[3] wiping _decimal
# # destroy decimal
# # cleanup[3] wiping numpy.fft._pocketfft_internal
# # cleanup[3] wiping numpy.polynomial.polyutils
# # cleanup[3] wiping numpy.random._pickle
# # cleanup[3] wiping numpy.random.mtrand
# # cleanup[3] wiping cython_runtime
# # cleanup[3] wiping numpy.random._bit_generator
# # cleanup[3] wiping numpy.random._common
# # cleanup[3] wiping binascii
# # cleanup[3] wiping _hashlib
# # cleanup[3] wiping bisect
# # cleanup[3] wiping _bisect
# # cleanup[3] wiping _random
# # cleanup[3] wiping numpy.random._bounded_integers
# # cleanup[3] wiping numpy.random._mt19937
# # cleanup[3] wiping numpy.random._philox
# # cleanup[3] wiping numpy.random._pcg64
# # cleanup[3] wiping numpy.random._sfc64
# # cleanup[3] wiping numpy.random._generator
# # cleanup[3] wiping numpy.ma
# # destroy numpy.ma.extras
# # cleanup[3] wiping numpy.ma.core
# # cleanup[3] wiping pytz
# # destroy pytz.exceptions
# # destroy pytz.lazy
# # destroy pytz.tzinfo
# # destroy pytz.tzfile
# # cleanup[3] wiping pandas.compat
# # destroy pandas.compat._optional
# # destroy pandas.compat.numpy
# # destroy pandas.compat.chainmap
# # cleanup[3] wiping distutils
# # destroy distutils.version
# # cleanup[3] wiping pandas._libs.tslibs
# # cleanup[3] wiping pandas._libs.tslibs.conversion
# # cleanup[3] wiping pandas._libs.tslibs.c_timestamp
# # cleanup[3] wiping pandas._libs.tslibs.nattype
# # cleanup[3] wiping pandas._libs.missing
# # cleanup[3] wiping pandas._libs.tslibs.np_datetime
# # cleanup[3] wiping pandas._libs.ops_dispatch
# # cleanup[3] wiping pandas._libs.tslibs.timezones
# # cleanup[3] wiping dateutil.tz
# # destroy dateutil.tz._common
# # destroy dateutil.tz._factories
# # destroy dateutil.tz.tz
# # cleanup[3] wiping six
# # cleanup[3] wiping six.moves
# # destroy six.moves.urllib
# # destroy six.moves
# # cleanup[3] wiping pandas._libs.tslibs.tzconversion
# # cleanup[3] wiping pandas._libs.tslibs.timedeltas
# # cleanup[3] wiping pandas._libs.tslibs.offsets
# # cleanup[3] wiping pandas._libs.tslibs.ccalendar
# # cleanup[3] wiping pandas._config.config
# # cleanup[3] wiping typing
# # cleanup[3] wiping pandas._libs.tslibs.strptime
# # cleanup[3] wiping calendar
# # cleanup[3] wiping dateutil.relativedelta
# # destroy calendar
# # cleanup[3] wiping pandas._libs.tslibs.fields
# # cleanup[3] wiping pandas._libs.tslibs.parsing
# # cleanup[3] wiping pandas._libs.tslibs.frequencies
# # cleanup[3] wiping string
# # cleanup[3] wiping _string
# # destroy _string
# # cleanup[3] wiping pandas._libs.tslibs.period
# # cleanup[3] wiping pandas._libs.tslibs.timestamps
# # cleanup[3] wiping pandas._libs.tslibs.resolution
# # cleanup[3] wiping pandas._libs.hashtable
# # cleanup[3] wiping pandas._libs.lib
# # cleanup[3] wiping pandas._libs.tslib
# # cleanup[3] wiping pandas._libs.interval
# # cleanup[3] wiping pandas._libs.algos
# # cleanup[3] wiping pandas.core.algorithms
# # cleanup[3] wiping pandas.util._decorators
# # cleanup[3] wiping inspect
# # destroy dis
# # destroy enum
# # cleanup[3] wiping _opcode
# # cleanup[3] wiping importlib
# # destroy importlib.util
# # cleanup[3] wiping importlib._bootstrap
# # cleanup[3] wiping importlib._bootstrap_external
# # cleanup[3] wiping importlib.machinery
# # cleanup[3] wiping pandas._libs.properties
# # cleanup[3] wiping pandas._libs.hashing
# # cleanup[3] wiping pandas.util._validators
# # cleanup[3] wiping pandas.core.common
# # cleanup[3] wiping pandas.compat.numpy.function
# # cleanup[3] wiping pandas.core.ops
# # destroy pandas.core.ops.roperator
# # destroy pandas.core.ops.dispatch
# # destroy pandas.core.ops.invalid
# # destroy pandas.core.ops.array_ops
# # destroy pandas.core.ops.common
# # destroy pandas.core.ops.docstrings
# # destroy pandas.core.ops.mask_ops
# # destroy pandas.core.ops.methods
# # cleanup[3] wiping pandas._libs.ops
# # cleanup[3] wiping pandas.core.ops.missing
# # cleanup[3] wiping pandas.core.missing
# # cleanup[3] wiping pandas.core.nanops
# # cleanup[3] wiping pandas.core.accessor
# # cleanup[3] wiping pandas.core.base
# # cleanup[3] wiping pandas.io.formats.console
# # cleanup[3] wiping pandas.core.arrays.datetimelike
# # cleanup[3] wiping pandas.tseries.frequencies
# # cleanup[3] wiping pandas.core.indexes.base
# # destroy pandas.core.dtypes.concat
# # cleanup[3] wiping pandas._libs.index
# # cleanup[3] wiping pandas._libs.join
# # cleanup[3] wiping pandas.io.formats.printing
# # cleanup[3] wiping pandas._libs.sparse
# # cleanup[3] wiping pandas.core.groupby
# # destroy pandas.core.groupby.categorical
# # destroy pandas.core.groupby.groupby
# # cleanup[3] wiping pandas.core.groupby.generic
# # destroy typing
# # cleanup[3] wiping copy
# # cleanup[3] wiping pandas.core.generic
# # destroy pandas.core.indexing
# # cleanup[3] wiping gc
# # destroy gc
# # cleanup[3] wiping pandas.core.tools.datetimes
# # cleanup[3] wiping pandas.util._exceptions
# # cleanup[3] wiping pandas._libs.indexing
# # cleanup[3] wiping pandas._libs.writers
# # cleanup[3] wiping pandas._libs.internals
# # cleanup[3] wiping pandas.io.formats.format
# # destroy decimal
# # cleanup[3] wiping unicodedata
# # destroy unicodedata
# # cleanup[3] wiping pandas.io.common
# # destroy mmap
# # destroy pathlib
# # cleanup[3] wiping gzip
# # destroy _compression
# # cleanup[3] wiping zipfile
# # destroy stat
# # destroy binascii
# # destroy threading
# # destroy zlib
# # cleanup[3] wiping importlib.abc
# # destroy _frozen_importlib_external
# # destroy importlib.machinery
# # cleanup[3] wiping pandas._libs.reshape
# # cleanup[3] wiping pandas._libs.window.aggregations
# # cleanup[3] wiping pandas.core.groupby.base
# # cleanup[3] wiping pandas._libs.window.indexers
# # cleanup[3] wiping pandas._libs.groupby
# # cleanup[3] wiping pandas.core.groupby.ops
# # destroy pandas.core.groupby.grouper
# # cleanup[3] wiping pandas._libs.reduction
# # cleanup[3] wiping pandas.core.computation.ops
# # cleanup[3] wiping pandas.core.computation.scope
# # destroy pprint
# # cleanup[3] wiping pandas.core.computation.expr
# # cleanup[3] wiping pandas.util._print_versions
# # destroy platform
# # cleanup[3] wiping pandas._libs.parsers
# # destroy pandas.io.common
# # cleanup[3] wiping csv
# # cleanup[3] wiping _csv
# # destroy _csv
# # cleanup[3] wiping pandas._libs.json
# # cleanup[3] wiping pandas.compat.pickle_compat
# # cleanup[3] wiping pandas.util._tester
# # cleanup[3] wiping tempfile
# # destroy errno
# # cleanup[3] wiping pandas._libs.testing
# # cleanup[3] wiping sys
# # cleanup[3] wiping builtins
# # destroy subprocess
# # destroy _weakref
# # destroy _heapq
# # destroy linecache
# # destroy numpy.core.multiarray
# # destroy numpy.core._string_helpers
# # destroy numpy.core._dtype
# # destroy numpy.core._type_aliases
# # destroy numpy.core._asarray
# # destroy numpy.core._exceptions
# # destroy numpy.core._methods
# # destroy numpy.core.fromnumeric
# # destroy numpy.core.shape_base
# # destroy numpy.core._ufunc_config
# # destroy numpy.core.arrayprint
# # destroy numpy.core.defchararray
# # destroy numpy.core.records
# # destroy numpy.core.function_base
# # destroy numpy.core.machar
# # destroy numpy.core.getlimits
# # destroy numpy.core.einsumfunc
# # destroy numpy.core._multiarray_tests
# # destroy numpy.core._add_newdocs
# # destroy numpy.core._dtype_ctypes
# # destroy numpy.core._internal
# # destroy numpy.core.numerictypes
# # destroy numpy.matrixlib
# # destroy numpy.lib.format
# # destroy numpy.random._pickle
# # destroy ctypes
# # destroy _sre
# # destroy sre_parse
# # destroy _struct
# # destroy six.moves.urllib_parse
# # destroy six.moves.urllib.error
# # destroy six.moves.urllib.request
# # destroy six.moves.urllib.response
# # destroy six.moves.urllib.robotparser
# # destroy _signal
# # destroy pandas.util._decorators
# # destroy pandas.util._validators
# # destroy pandas.util._exceptions
# # destroy pandas.util._print_versions
# # destroy pandas.util._tester
# # destroy pandas.core.groupby
# # destroy pickle
# # destroy pandas.compat.pickle_compat
# # destroy struct
# # destroy bz2
# # destroy gzip
# # destroy tempfile
# # destroy zipfile
# # destroy lzma
# # destroy json
# # destroy pandas.core.groupby.base
# # destroy json.scanner
# # destroy _json
# # destroy _opcode
# # destroy numpy.ma.core
# # destroy ntpath
# # destroy posixpath
# # destroy numpy.linalg.lapack_lite
# # destroy numpy.linalg._umath_linalg
# # destroy contextlib
# # destroy shutil
# # destroy io
# # destroy io
# # destroy numpy.core.numeric
# # destroy numpy.fft._pocketfft_internal
# # destroy numpy.linalg
# # destroy numpy.polynomial.polyutils
# # destroy select
# # destroy importlib.abc
# # destroy _imp
# # destroy locale
# # destroy pandas.core.groupby.ops
# # destroy csv
# # destroy pandas._libs.json
# # destroy _frozen_importlib

# %%
region = boto3.session.Session().region_name

bucket = 'sagemaker-us-east-2-169274280855'
preprocessed_prefix = 'jc/aiops/data'
output_train_data = 's3://{}/{}/{}/'.format(bucket, preprocessed_prefix,'train')

# %%
# %%time
#### all low level APIs
client = boto3.client('sagemaker')
_job_name = 'aiops-processing-job'
response = client.create_processing_job(
    ProcessingInputs=[
        {
            'InputName': 'string',
            'S3Input': {
                'S3Uri': data_location,
                'LocalPath': '/opt/ml/processing/input',
                'S3DataType': 'S3Prefix',
                'S3InputMode': 'File',
                'S3DataDistributionType': 'ShardedByS3Key',
                'S3CompressionType': 'None'
            }
        },
    ],
    ProcessingOutputConfig={
        'Outputs': [
            {
                'OutputName': 'train_data',
                'S3Output': {
                    'S3Uri': output_train_data,
                    'LocalPath': '/opt/ml/processing/output/train',
                    'S3UploadMode': 'EndOfJob'
                }
            }
        ]
    },
    ProcessingJobName=_job_name,
    ProcessingResources={
        'ClusterConfig': {
            'InstanceCount': 1,
            'InstanceType':'ml.c5.xlarge',
            'VolumeSizeInGB': 10
        }
    },
    StoppingCondition={
        'MaxRuntimeInSeconds': 1200
    },
    AppSpecification={
        'ImageUri': image,
        'ContainerEntrypoint': ['python3','preprocessing.py']
    },
    Environment={
        'mode': 'python'
    },
    RoleArn=role
)
# Out:
# CPU times: user 13.9 ms, sys: 182 µs, total: 14.1 ms
# Wall time: 84.3 ms

# %%
import time
while 1:
    print(client.list_processing_jobs()['ProcessingJobSummaries'][0]['ProcessingJobStatus'])
    time.sleep(10)
# Out:
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# InProgress
# Completed
# Completed
# Completed
# Completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-064b1706d607> in <module>()
#       2 while 1:
#       3     print(client.list_processing_jobs()['ProcessingJobSummaries'][0]['ProcessingJobStatus'])
# ----> 4     time.sleep(10)
#
# KeyboardInterrupt:
